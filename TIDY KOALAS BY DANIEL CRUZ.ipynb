# %%
import databricks.koalas as ks

# %%
import pandas as pd
import numpy as np

# %%
pwd()
# Out:
# '/home/h110-10/anaconda3/bin'

# %%
data = pd.read_csv('weather01.txt',delimiter="\t")

# %%
data1=ks.from_pandas(data)

# %%
data1.head(10)
# Out:
#         X year month                   measure                X1        X2
# 0  1     1 2014    12          Max.TemperatureF  ...
# 1  2     2 2014    12         Mean.TemperatureF  ...
# 2  3     3 2014    12          Min.TemperatureF  ...
# 3  4     4 2014    12            Max.Dew.PointF  ...
# 4  5     5 2014    12            MeanDew.PointF  ...
# 5  6     6 2014    12             Min.DewpointF  ...
# 6  7     7 2014    12              Max.Humidity  ...
# 7  8     8 2014    12             Mean.Humidity  ...
# 8  9     9 2014    12              Min.Humidity  ...
# 9  10   10 2014    12  Max.Sea.Level.PressureIn  ...

# %%
data1.info()
# Out:
# ---------------------------------------------------------------------------
# PandasNotImplementedError                 Traceback (most recent call last)
# <ipython-input-19-9fb4e35ecd1e> in <module>
# ----> 1 data1.info()
#
# ~/anaconda3/lib/python3.7/site-packages/databricks/koalas/missing/__init__.py in unsupported_function(*args, **kwargs)
#      22     def unsupported_function(*args, **kwargs):
#      23         raise PandasNotImplementedError(class_name=class_name, method_name=method_name,
# ---> 24                                         reason=reason)
#      25
#      26     def deprecated_function(*args, **kwargs):
#
# PandasNotImplementedError: The method `pd.DataFrame.info()` is not implemented yet.

# %%
data
# Out:
#           X year month                   measure                X1        X2
# 0    1     1 2014    12          Max.TemperatureF  ...
# 1    2     2 2014    12         Mean.TemperatureF  ...
# 2    3     3 2014    12          Min.TemperatureF  ...
# 3    4     4 2014    12            Max.Dew.PointF  ...
# 4    5     5 2014    12            MeanDew.PointF  ...
# 5    6     6 2014    12             Min.DewpointF  ...
# 6    7     7 2014    12              Max.Humidity  ...
# 7    8     8 2014    12             Mean.Humidity  ...
# 8    9     9 2014    12              Min.Humidity  ...
# 9    10   10 2014    12  Max.Sea.Level.PressureIn  ...
# 10   11   11 2014    12 Mean.Sea.Level.PressureIn  ...
# 11   12   12 2014    12  Min.Sea.Level.PressureIn  ...
# 12   13   13 2014    12       Max.VisibilityMiles  ...
# 13   14   14 2014    12      Mean.VisibilityMiles  ...
# 14   15   15 2014    12       Min.VisibilityMiles  ...
# 15   16   16 2014    12         Max.Wind.SpeedMPH  ...
# ...

# %%
data
# Out:
#           X year month                   measure                X1        X2
# 0    1     1 2014    12          Max.TemperatureF  ...
# 1    2     2 2014    12         Mean.TemperatureF  ...
# 2    3     3 2014    12          Min.TemperatureF  ...
# 3    4     4 2014    12            Max.Dew.PointF  ...
# 4    5     5 2014    12            MeanDew.PointF  ...
# 5    6     6 2014    12             Min.DewpointF  ...
# 6    7     7 2014    12              Max.Humidity  ...
# 7    8     8 2014    12             Mean.Humidity  ...
# 8    9     9 2014    12              Min.Humidity  ...
# 9    10   10 2014    12  Max.Sea.Level.PressureIn  ...
# 10   11   11 2014    12 Mean.Sea.Level.PressureIn  ...
# 11   12   12 2014    12  Min.Sea.Level.PressureIn  ...
# 12   13   13 2014    12       Max.VisibilityMiles  ...
# 13   14   14 2014    12      Mean.VisibilityMiles  ...
# 14   15   15 2014    12       Min.VisibilityMiles  ...
# 15   16   16 2014    12         Max.Wind.SpeedMPH  ...
# ...

# %%
data
